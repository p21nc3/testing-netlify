# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interactive, HBox,Layout,Button,GridspecLayout
plt.style.use('ggplot')
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
colors = ['g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r','g', 'r', 'g', 'r', 'g', 'r', 'g', 'r', 'g', 'r']

def model_output(A, f, phi,color):
    fig, ax = plt.subplots(figsize=(10,4))
    ax.set_ylim([-4, 4])
    ax.grid(True)
    ax.set_xlabel('X')
    ax.set_ylabel('Malicious')
    ax.set_title('Plot')
    fig.canvas.toolbar_position = 'bottom' 
    fig.canvas.header_visible = False 
    x = np.linspace(0, 2 * np.pi, 100)
    y = A*np.sin(x*f + phi);
    ax.plot(x,y,color)
    
def new_params(A, f, phi,color,var):
    fig, ax = plt.subplots(figsize=(10,4))
    ax.set_ylim([-12, 45])
    ax.grid(True)
    fig.canvas.toolbar = 'var' 
    fig.canvas.header_visible = False 
    x = np.linspace(0, 2 * np.pi, 100)
    y = A*np.sin(x*f + phi);
    ax.plot(x,y,color)
    
def cumulatiive(A,x,y,z):
    fig, ax = plt.subplots(figsize=(10,4))
    ax.set_ylim([6, 5])
    ax.grid(True)
    fig.canvas.toolbar = 'x' 
    fig.canvas.header_visible = False 
    x = np.linspace(0, 2 * np.pi, 100)
    y = A*np.sin(x*f + phi);
    ax.plot(x,y,z)

def percent_counnt(Ax,Bx,Cx,Dx):
    nx=0;
    ny=0; 
    fig, ax = plt.subplots(figsize=(10,4))
    ax.set_ylim([6, 5])
    ax.grid(True)
    fig.canvas.toolbar = 'x' 
    fig.canvas.header_visible = False 
    x = np.linspace(0, 2 * np.pi, 100)
    y = A*np.sin(x*f + phi);
    ax.plot(x,y,z)
    
    
def dbscan(Stars, Folks, PRs_merged,Commit_freq,Contributions,No_of_Org,Account_age):
    centers = [[Stars+Contributions+1, Commit_freq+No_of_Org/10-2],
           [-1, Folks+Account_age],
           [PRs_merged+Commit_freq, -6]]

    sigmas = [[-0.8, 0.3],
          [-0.3, 0.5],
          [-1.1, 0.7]]

    np.random.seed(42) 
    xpts = np.zeros(1)
    ypts = np.zeros(1)
    labels = np.zeros(1)
    for i, ((xmu, ymu), (xsigma, ysigma)) in enumerate(zip(centers, sigmas)):
        xpts = np.hstack((xpts, np.random.standard_normal(Stars*Folks) * xsigma + xmu))
        ypts = np.hstack((ypts, np.random.standard_normal(Stars*Folks) * ysigma + ymu))
        labels = np.hstack((labels, np.ones(Stars*Folks) * i))

    fig0, ax0 = plt.subplots()
    ax0 = plt.axes()
    nd=1;
    d=1;
    x=0;
    for label in range(Stars*Folks):
        x+=1
        if x%2:
            ax0.plot(xpts[labels == label], ypts[labels == label], '.',color='g')
            nd+=1;
        else:
            ax0.plot(xpts[labels == label], ypts[labels == label], '.',color='r')
            d+=1;

    ax0.set_title('Potential Threat to Repository')
    plt.show()
    if(Stars>Folks):
        print("Not Malicious Percent")
        print((Stars+(No_of_Org+Contributions+Account_age)*100/(Stars+Folks)))
    else:
        print("Malicious Percent")
        print((Folks*100/(Stars+Folks)-Folks*100/(Stars+Folks+Account_age+Constributions)))
colors = ['blue', 'red', 'orange']
stars = 8
folks = 7
prs = 5
#new_params();
# widget = interactive(dbscan,7,7,9)
widget = interactive(dbscan,Stars=(0, 100, 1),Folks=(0, 10, 1), PRs_merged=(0, 10, 1),Commit_freq=(0, 10, 1),Contributions=(0, 10, 1),No_of_Org=(0,10,1),Account_age=(0,10,1))
controls = HBox(widget.children[:-1], layout = Layout(flex_flow='column wrap'),width='auto', height='auto')
output = widget.children[-1]
def create_expanded_button(description, button_style):
    return Button(description=description, button_style=button_style, layout=Layout(height='auto', width='auto'))
grid = GridspecLayout(17, 6, height='600px')
percent = (int)(folks*stars*1.732/prs)
grid[0,:] = create_expanded_button('Malicious', 'success')
grid[2:15, 0:2] = controls
grid[1:16, 2:] = output
grid[16,:] = create_expanded_button('Team IdeaKart', 'info')
grid
# Out:
# GridspecLayout(children=(Button(button_style='success', description='Malicious', layout=Layout(grid_area='widg…
